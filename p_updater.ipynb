# %%
import subprocess

outdated = subprocess.run(['pip', 'list', '--outdated'], capture_output=True, text=True)

print(outdated.stdout)
# Out:
# Package Version Latest Type
# ------- ------- ------ -----
# pandas  3.0.4   3.0.6  wheel
